# %%
#Introducimos las bibliotecas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import matplotlib.dates as mdates

# %%
#Usamos el DataFrame
df0=pd.read_csv('vid18_180219.dat', delimiter = ',')

# %%
#Encabezado
df0.head()
# Out:
#              TIMESTAMP  RECORD  batt_volt_Min  logger_temp  short_up_Avg  \
# 0  2018-05-11 20:10:00    7980          12.31        25.87     -5.499501
# 1  2018-05-11 20:20:00    7981          12.30        25.37     -4.934265
# 2  2018-05-11 20:30:00    7982          12.28        24.91     -4.615617
# 3  2018-05-11 20:40:00    7983          12.27        24.47     -4.433317
# 4  2018-05-11 20:50:00    7984          12.26        24.09     -2.861873
#
#    short_dn_Avg  long_up_Avg  long_dn_Avg  cnr4_T_C_Avg  cnr4_T_K_Avg  \
# 0      1.581859    -82.19471    -4.002829      23.26391      296.4139
# 1      1.946161    -80.00718    -1.978131      22.75189      295.9019
# 2      2.407313    -76.72183    -1.868207      22.43361      295.5836
# 3      2.523456    -73.10189    -3.367143      22.08901      295.2390
# 4      3.898805    -70.19295     0.915511      22.08449      295.2345
#
#        ...       Result2_Avg  Result3_Avg  Result4_Avg  Result5_Avg  \
# ...

# %%
#Creamos un DataFrame con las columnas de TIMESTAMP y AirTC_Avg
df0=pd.DataFrame({"TIME" : df0.TIMESTAMP,"TEMP" : df0.AirTC_Avg})

df0.head()
# Out:
#                   TIME   TEMP
# 0  2018-05-11 20:10:00  23.50
# 1  2018-05-11 20:20:00  22.96
# 2  2018-05-11 20:30:00  22.73
# 3  2018-05-11 20:40:00  22.40
# 4  2018-05-11 20:50:00  22.46

# %%
#Tipos de Variables
df0.dtypes
# Out:
# TIME     object
# TEMP    float64
# dtype: object

# %%
df0['TIME'] = pd.to_datetime(df0.apply(lambda x: x['TIME'], 1))

# %%
#Construimos una tabla de unidades de frío acumuladas UF24 por cada día completo de datos a partir del 1 de Noviembre del 2018
df0=df0[(df0["TIME"] > "2018-11-1")]
df0.head()
# Out:
#                      TIME  TEMP
# 24936 2018-11-01 00:10:00  8.89
# 24937 2018-11-01 00:20:00  8.66
# 24938 2018-11-01 00:30:00  8.52
# 24939 2018-11-01 00:40:00  8.47
# 24940 2018-11-01 00:50:00  8.58

# %%
#Añadimos columnas para Hora-Dia-Mes-Año
df0['HORA'] = df0['TIME'].dt.hour
df0['DIA'] = df0['TIME'].dt.day
df0["MES"] = df0["TIME"].dt.month
df0["AÑO"] = df0["TIME"].dt.year
#Borramos columna TIME
f=len(df0)
df0.index = np.arange(0,f)
df0 = df0.drop(["TIME"], 1)

# %%
#Encabezado
df0.head()
# Out:
#    TEMP  HORA  DIA  MES   AÑO
# 0  8.89     0    1   11  2018
# 1  8.66     0    1   11  2018
# 2  8.52     0    1   11  2018
# 3  8.47     0    1   11  2018
# 4  8.58     0    1   11  2018

# %%
df=pd.DataFrame({})
df["TEMP"]=df0.groupby(["AÑO","MES","DIA","HORA"])["TEMP"].transform("mean")
df.head()
# Out:
#     TEMP
# 0  8.624
# 1  8.624
# 2  8.624
# 3  8.624
# 4  8.624

# %%
#Agregamos dos columnas nuevas con las temperaturas Mínima y Máximas diarias del periodo de tiempo analizado
df["TMIN"]=df0.groupby(["AÑO","MES","DIA"])["TEMP"].transform("min")
df["TMAX"]=df0.groupby(["AÑO","MES","DIA"])["TEMP"].transform("max")
df["HORA"]=df0.HORA
df["DIA"]=df0.DIA
df["MES"]=df0.MES
df["AÑO"]=df0.AÑO
df.head()
# Out:
#     TEMP   TMIN   TMAX  HORA  DIA  MES   AÑO
# 0  8.624  6.096  29.58     0    1   11  2018
# 1  8.624  6.096  29.58     0    1   11  2018
# 2  8.624  6.096  29.58     0    1   11  2018
# 3  8.624  6.096  29.58     0    1   11  2018
# 4  8.624  6.096  29.58     0    1   11  2018

# %%
#Eliminamos filas duplicadas
df=df.drop_duplicates()
f=len(df)
df.index = np.arange(0,f)
df.head()
# Out:
#        TEMP   TMIN   TMAX  HORA  DIA  MES   AÑO
# 0  8.624000  6.096  29.58     0    1   11  2018
# 1  8.493333  6.096  29.58     1    1   11  2018
# 2  8.690000  6.096  29.58     2    1   11  2018
# 3  8.846667  6.096  29.58     3    1   11  2018
# 4  7.397500  6.096  29.58     4    1   11  2018

# %%
#Calculamos el indice UF24
count=[]
for i in range (0,len(df)):
    z=df.TEMP[i]
    if (z<=1.4) :
        j=0
    if (z>1.4 and z<=2.4) :
        j=0.5   
    if (z>=2.5 and z<=9.1) :
        j=1
    if (z>=9.2 and z<=12.4) :
        j=0.5  
    if (z>=12.5 and z<=15.9) :
        j=0
    if (z>=16 and z<=18) :
        j=-0.5
    if (z>18) :
        j=-1
    count.append(j)
df["UF24"]=count

# %%
#Encabezado
df.head()
# Out:
#        TEMP   TMIN   TMAX  HORA  DIA  MES   AÑO  UF24
# 0  8.624000  6.096  29.58     0    1   11  2018   1.0
# 1  8.493333  6.096  29.58     1    1   11  2018   1.0
# 2  8.690000  6.096  29.58     2    1   11  2018   1.0
# 3  8.846667  6.096  29.58     3    1   11  2018   1.0
# 4  7.397500  6.096  29.58     4    1   11  2018   1.0

# %%
#Contruimos una gráfica con Matplotlib y mostramos la evolución de las temperaturas mínima y máxima en la misma gráfica
#Para ello debemos eliminar datos duplicados 
#df1=df
df1=df.drop(["TEMP", "HORA", "UF24"],1)
df1=df1.drop_duplicates()
f=len(df1)
df1.index = np.arange(0,f)
df1.head()



df2=pd.DataFrame({})
df2["day"]=df1.DIA
df2["month"]=df1.MES
df2["year"]=df1.AÑO
df2.index = np.arange(0,f)
df2.head()
j=pd.to_datetime(df2)

df1["FECHA"]=j


#Ya que no tenemos dato duplicados podemos graficar
sns.set(rc={'figure.figsize':(12,8.27)})

df4 = df1[['TMAX', "TMIN"]]
fig=plt.figure(); df4.plot(); plt.legend(loc='lower left')
plt.title("Evolución de las temperaturas mínima y máxima")
plt.ylabel("Temperatura ºC")
plt.grid(True)
plt.savefig('EvoTemp_TMINyTMAX',plt=2000)
plt.show()

# %%
#Construimos una gráfica con Matplotlib, donde se grafique la acumulación de horas frío desde el primer día (suma de UF24). 
#Para ello debemos eliminar datos duplicados 
df3=df.drop(["TEMP", "TMIN","TMAX"],1)
df3=df3.drop_duplicates()
f=len(df3)
df3.index = np.arange(0,f)
df3.head()

df2=pd.DataFrame({})
df2["day"]=df3.DIA
df2["month"]=df3.MES
df2["year"]=df3.AÑO
df2["hour"]=df3.HORA
df2.index = np.arange(0,f)
df2.head()
j=pd.to_datetime(df2)

df3["FECHA"]=j
df3["SUF"]=df3["UF24"].cumsum()

df4 = df3[["SUF"]]
plt.figure(figsize=(20,19))
fig=plt.figure(); df4.plot(); plt.legend(loc='lower left')
plt.title("La acumulación de horas frío desde el primer día (1 de Noviembre del 2018)")
plt.ylabel("Temperatura ºC")
plt.grid(True)
plt.savefig('AcumHorasDeFrio',plt=2000)
plt.show()

# %%
#Encabezado
df1.head()
# Out:
#      TMIN   TMAX  DIA  MES   AÑO      FECHA
# 0   6.096  29.58    1   11  2018 2018-11-01
# 1  10.020  31.35    2   11  2018 2018-11-02
# 2  10.160  30.48    3   11  2018 2018-11-03
# 3  11.160  31.39    4   11  2018 2018-11-04
# 4  11.130  31.21    5   11  2018 2018-11-05

# %%
#Encabezado
df3.head()
# Out:
#    HORA  DIA  MES   AÑO  UF24               FECHA  SUF
# 0     0    1   11  2018   1.0 2018-11-01 00:00:00  1.0
# 1     1    1   11  2018   1.0 2018-11-01 01:00:00  2.0
# 2     2    1   11  2018   1.0 2018-11-01 02:00:00  3.0
# 3     3    1   11  2018   1.0 2018-11-01 03:00:00  4.0
# 4     4    1   11  2018   1.0 2018-11-01 04:00:00  5.0
